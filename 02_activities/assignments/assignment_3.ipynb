# %% [markdown]
# # Assignment 3

# %% [markdown]
# In this assigment, we will work with the *Forest Fire* data set. Please download the data from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/dataset/162/forest+fires). Extract the data files into the subdirectory: `../data/fires/` (relative to `./src/`).
#
# ## Objective
#
# + The model objective is to predict the area affected by forest fires given the features set.
# + The objective of this exercise is to assess your ability to construct and evaluate model pipelines.
# + Please note: the instructions are not meant to be 100% prescriptive, but instead they are a set of minimum requirements. If you find predictive performance gains by applying additional steps, by all means show them.

# %% [markdown]
# ## Variable Description
#
# From the description file contained in the archive (`forestfires.names`), we obtain the following variable descriptions:
#
# 1. X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
# 2. Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
# 3. month - month of the year: "jan" to "dec"
# 4. day - day of the week: "mon" to "sun"
# 5. FFMC - FFMC index from the FWI system: 18.7 to 96.20
# 6. DMC - DMC index from the FWI system: 1.1 to 291.3
# 7. DC - DC index from the FWI system: 7.9 to 860.6
# 8. ISI - ISI index from the FWI system: 0.0 to 56.10
# 9. temp - temperature in Celsius degrees: 2.2 to 33.30
# 10. RH - relative humidity in %: 15.0 to 100
# 11. wind - wind speed in km/h: 0.40 to 9.40
# 12. rain - outside rain in mm/m2 : 0.0 to 6.4
# 13. area - the burned area of the forest (in ha): 0.00 to 1090.84

# %% [markdown]
# ### Specific Tasks
#
# + Construct four model pipelines, out of combinations of the following components:
#
#     + Preprocessors:
#
#         - A simple processor that only scales numeric variables and recodes categorical variables.
#         - A transformation preprocessor that scales numeric variables and applies a non-linear transformation.
#
#     + Regressor:
#
#         - A baseline regressor, which could be a [K-nearest neighbours model]() or a linear model like [Lasso](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html) or [Ridge Regressors](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ridge_regression.html).
#         - An advanced regressor of your choice (e.g., Bagging, Boosting, SVR, etc.). TIP: select a tree-based method such that it does not take too long to run SHAP further below.
#
# + Evaluate tune and evaluate each of the four model pipelines.
#
#     - Select a [performance metric](https://scikit-learn.org/stable/modules/linear_model.html) out of the following options: explained variance, max error, root mean squared error (RMSE), mean absolute error (MAE), r-squared.
#     - *TIPS*:
#
#         * Out of the suggested metrics above, [some are correlation metrics, but this is a prediction problem](https://www.tmwr.org/performance#performance). Choose wisely (and don't choose the incorrect options.)
#
# + Select the best-performing model and explain its predictions.
#
#     - Provide local explanations.
#     - Obtain global explanations and recommend a variable selection strategy.
#
# + Export your model as a pickle file.
#
#
# You can work on the Jupyter notebook, as this experiment is fairly short (no need to use sacred).

# %% [markdown]
# # Load the data
#
# Place the files in the ../../05_src/data/fires/ directory and load the appropriate file.

# %%
# Load the libraries as required.

import os
import sys
import pandas as pd
import numpy as np
import dask.dataframe as dd
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
import pickle
import shap
from sklearn import linear_model

# %%
# Load data
columns = [
    'coord_x', 'coord_y', 'month', 'day', 'ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh', 'wind', 'rain', 'area' 
]
fires_dt = (pd.read_csv('../../05_src/data/fires/forestfires.csv', header = 0, names = columns))
fires_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   coord_x  517 non-null    int64
#  1   coord_y  517 non-null    int64
#  2   month    517 non-null    object
#  3   day      517 non-null    object
#  4   ffmc     517 non-null    float64
#  5   dmc      517 non-null    float64
#  6   dc       517 non-null    float64
#  7   isi      517 non-null    float64
#  8   temp     517 non-null    float64
#  9   rh       517 non-null    int64
#  10  wind     517 non-null    float64
#  11  rain     517 non-null    float64
#  12  area     517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %% [markdown]
# # Get X and Y
#
# Create the features data frame and target data.

# %%
X = fires_dt.drop(columns = 'area')
Y = fires_dt['area']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)

# %% [markdown]
# # Preprocessing
#
# Create two [Column Transformers](https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html), called preproc1 and preproc2, with the following guidelines:
#
# - Numerical variables
#
#     * (Preproc 1 and 2) Scaling: use a scaling method of your choice (Standard, Robust, Min-Max).
#     * Preproc 2 only:
#
#         + Choose a transformation for any of your input variables (or several of them). Evaluate if this transformation is convenient.
#         + The choice of scaler is up to you.
#
# - Categorical variables:
#
#     * (Preproc 1 and 2) Apply [one-hot encoding](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html) where appropriate.
#
#
# + The only difference between preproc1 and preproc2 is the non-linear transformation of the numerical variables.

# %% [markdown]
# ### Preproc 1
#
# Create preproc1 below.
#
# + Numeric: scaled variables, no other transforms.
# + Categorical: one-hot encoding.

# %%
num_cols = ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh', 'wind', 'rain']
cat_cols = ['coord_x', 'coord_y','month', 'day']

pipe_num = Pipeline([ 
    ('standardizer', StandardScaler())
])

pipe_cat = Pipeline([ 
    ('onehot', OneHotEncoder(handle_unknown='infrequent_if_exist', drop = 'if_binary')) 
])

transform_col_1 = ColumnTransformer([
    ('num_transforms', pipe_num, num_cols),
    ('cat_transforms', pipe_cat, cat_cols)
])

transform_col_1
# Out:
# ColumnTransformer(transformers=[('num_transforms',
#                                  Pipeline(steps=[('standardizer',
#                                                   StandardScaler())]),
#                                  ['ffmc', 'dmc', 'dc', 'isi', 'temp', 'rh',
#                                   'wind', 'rain']),
#                                 ('cat_transforms',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='infrequent_if_exist'))]),
#                                  ['coord_x', 'coord_y', 'month', 'day'])])

# %% [markdown]
# ### Preproc 2
#
# Create preproc1 below.
#
# + Numeric: scaled variables, non-linear transformation to one or more variables.
# + Categorical: one-hot encoding.

# %%
num_cols = ['ffmc', 'dmc', 'dc', 'isi'] 
num_cols_transform = ['temp', 'rh', 'wind', 'rain'] 
cat_cols = ['coord_x', 'coord_y','month', 'day']

pipe_num_sim = Pipeline([ 
    ('standardizer', StandardScaler()),
])

pipe_num_yj = Pipeline([ 
    ('standardizer', StandardScaler()),
    ('transformer', PowerTransformer(method='yeo-johnson'))
])

pipe_cat = Pipeline([ 
    ('onehot', OneHotEncoder(handle_unknown = 'infrequent_if_exist' ,drop = 'if_binary')) 
])

transform_col_2 = ColumnTransformer([
    ('num_sim_transforms', pipe_num_sim, num_cols),
    ('num_yj_transforms', pipe_num_yj, num_cols_transform),
    ('cat_transforms', pipe_cat, cat_cols)
])

transform_col_2
# Out:
# ColumnTransformer(transformers=[('num_sim_transforms',
#                                  Pipeline(steps=[('standardizer',
#                                                   StandardScaler())]),
#                                  ['ffmc', 'dmc', 'dc', 'isi']),
#                                 ('num_yj_transforms',
#                                  Pipeline(steps=[('standardizer',
#                                                   StandardScaler()),
#                                                  ('transformer',
#                                                   PowerTransformer())]),
#                                  ['temp', 'rh', 'wind', 'rain']),
#                                 ('cat_transforms',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='infrequent_if_exist'))]),
# ...

# %% [markdown]
# ## Model Pipeline
#
#
# Create a [model pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html):
#
# + Add a step labelled `preprocessing` and assign the Column Transformer from the previous section.
# + Add a step labelled `regressor` and assign a regression model to it.
#
# ## Regressor
#
# + Use a regression model to perform a prediction.
#
#     - Choose a baseline regressor, tune it (if necessary) using grid search, and evaluate it using cross-validation.
#     - Choose a more advance regressor, tune it (if necessary) using grid search, and evaluate it using cross-validation.
#     - Both model choices are up to you, feel free to experiment.

# %%
# Pipeline A = preproc1 + baseline

pipe_a = Pipeline([
    ('preprocess', transform_col_1),
    ('regressor', linear_model.Lasso(alpha=1))
])
pipe_a
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler())]),
#                                                   ['ffmc', 'dmc', 'dc', 'isi',
#                                                    'temp', 'rh', 'wind',
#                                                    'rain']),
#                                                  ('cat_transforms',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='infrequent_if_exist'))]),
#                                                   ['coord_x', 'coord_y',
# ...

# %%
# Pipeline B = preproc2 + baseline

pipe_b = Pipeline([
    ('preprocess', transform_col_2),
    ('regressor', linear_model.Lasso(alpha=1))
])
pipe_b
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_sim_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler())]),
#                                                   ['ffmc', 'dmc', 'dc', 'isi']),
#                                                  ('num_yj_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler()),
#                                                                   ('transformer',
#                                                                    PowerTransformer())]),
#                                                   ['temp', 'rh', 'wind',
#                                                    'rain']),
#                                                  ('cat_transforms',
# ...

# %%
# Pipeline C = preproc1 + advanced model

pipe_c = Pipeline([
    ('preprocess', transform_col_1),
    ('regressor', RandomForestRegressor(criterion = 'squared_error', max_depth=3))
])
pipe_c
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler())]),
#                                                   ['ffmc', 'dmc', 'dc', 'isi',
#                                                    'temp', 'rh', 'wind',
#                                                    'rain']),
#                                                  ('cat_transforms',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='infrequent_if_exist'))]),
#                                                   ['coord_x', 'coord_y',
# ...

# %%
# Pipeline D = preproc2 + advanced model

pipe_d = Pipeline([
    ('preprocess', transform_col_2),
    ('regressor', RandomForestRegressor(criterion = 'squared_error', max_depth=3))
])
pipe_d
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_sim_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler())]),
#                                                   ['ffmc', 'dmc', 'dc', 'isi']),
#                                                  ('num_yj_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler()),
#                                                                   ('transformer',
#                                                                    PowerTransformer())]),
#                                                   ['temp', 'rh', 'wind',
#                                                    'rain']),
#                                                  ('cat_transforms',
# ...

# %% [markdown]
# # Tune Hyperparams
#
# + Perform GridSearch on each of the four pipelines.
# + Tune at least one hyperparameter per pipeline.
# + Experiment with at least four value combinations per pipeline.

# %%
scoring = ['neg_root_mean_squared_error']

#get pipeline parameters
pipe_a.get_params()

#define parameters to test
param_grid = {
    'regressor__alpha': [1, 2, 3],
    'regressor__selection': ['cyclic', 'random'],
    }

grid_cv = GridSearchCV(
    estimator=pipe_a, 
    param_grid=param_grid, 
    scoring = scoring, 
    cv = 5,
    refit = 'neg_root_mean_squared_error')
grid_cv.fit(X_train, Y_train)

res_a = pd.DataFrame(grid_cv.cv_results_)
best_param_a = grid_cv.best_params_
best_estimator_a = grid_cv.best_estimator_
# Out:
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# ...

# %%
res_a
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004421      0.001767         0.001727        0.000309
# 1       0.003540      0.000280         0.001555        0.000128
# 2       0.003282      0.000243         0.001612        0.000124
# 3       0.003227      0.000121         0.001615        0.000123
# 4       0.003047      0.000047         0.001489        0.000016
# 5       0.003051      0.000107         0.001485        0.000033
#
#    param_regressor__alpha param_regressor__selection  \
# 0                       1                     cyclic
# 1                       1                     random
# 2                       2                     cyclic
# 3                       2                     random
# 4                       3                     cyclic
# 5                       3                     random
#
#                                               params  \
# 0  {'regressor__alpha': 1, 'regressor__selection'...
# ...

# %%
scoring = ['neg_root_mean_squared_error']

#get pipeline parameters
pipe_b.get_params()

#define parameters to test
param_grid = {
    'regressor__alpha': [1, 2, 3],
    'regressor__selection': ['cyclic', 'random'],
    }

grid_cv = GridSearchCV(
    estimator=pipe_b, 
    param_grid=param_grid, 
    scoring = scoring, 
    cv = 5,
    refit = 'neg_root_mean_squared_error')
grid_cv.fit(X_train, Y_train)

res_b = pd.DataFrame(grid_cv.cv_results_)
best_param_b = grid_cv.best_params_
best_estimator_b = grid_cv.best_estimator_
# Out:
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# ...

# %%
res_b
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.007209      0.000709         0.002240        0.000197
# 1       0.006415      0.000211         0.002097        0.000052
# 2       0.006265      0.000182         0.002041        0.000033
# 3       0.006374      0.000233         0.002031        0.000024
# 4       0.006589      0.000418         0.002149        0.000125
# 5       0.006544      0.000534         0.002108        0.000071
#
#    param_regressor__alpha param_regressor__selection  \
# 0                       1                     cyclic
# 1                       1                     random
# 2                       2                     cyclic
# 3                       2                     random
# 4                       3                     cyclic
# 5                       3                     random
#
#                                               params  \
# 0  {'regressor__alpha': 1, 'regressor__selection'...
# ...

# %%
scoring = ['neg_root_mean_squared_error']

#get pipeline parameters
pipe_c.get_params()

#define parameters to test
param_grid = {
    'regressor__min_samples_split': [2, 3],
    'regressor__min_samples_leaf': [1, 2],
    'regressor__bootstrap': [True, False]
    }

grid_cv = GridSearchCV(
    estimator=pipe_c, 
    param_grid=param_grid, 
    scoring = scoring, 
    cv = 5,
    refit = 'neg_root_mean_squared_error')
grid_cv.fit(X_train, Y_train)

res_c = pd.DataFrame(grid_cv.cv_results_)
best_param_c = grid_cv.best_params_
best_estimator_c = grid_cv.best_estimator_
# Out:
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# ...

# %%
res_c
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.062581      0.001710         0.003588        0.000180
# 1       0.061247      0.000495         0.003344        0.000101
# 2       0.061878      0.000451         0.003340        0.000085
# 3       0.062391      0.001620         0.003385        0.000182
# 4       0.048193      0.002653         0.003327        0.000112
# 5       0.048110      0.002777         0.003329        0.000103
# 6       0.050212      0.001763         0.003359        0.000138
# 7       0.050243      0.002264         0.003266        0.000123
#
#    param_regressor__bootstrap  param_regressor__min_samples_leaf  \
# 0                        True                                  1
# 1                        True                                  1
# 2                        True                                  2
# 3                        True                                  2
# ...

# %%
scoring = ['neg_root_mean_squared_error']

#get pipeline parameters
pipe_d.get_params()

#define parameters to test
param_grid = {
    'regressor__min_samples_split': [2, 3],
    'regressor__min_samples_leaf': [1, 2],
    'regressor__bootstrap': [True, False]
    }

grid_cv = GridSearchCV(
    estimator=pipe_d, 
    param_grid=param_grid, 
    scoring = scoring, 
    cv = 5,
    refit = 'neg_root_mean_squared_error')
grid_cv.fit(X_train, Y_train)

res_d = pd.DataFrame(grid_cv.cv_results_)
best_param_d = grid_cv.best_params_
best_estimator_d = grid_cv.best_estimator_
# Out:
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
# Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
# ...

# %%
res_d
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.065645      0.001037         0.003990        0.000192
# 1       0.064623      0.000688         0.003887        0.000130
# 2       0.065820      0.000279         0.004061        0.000239
# 3       0.065458      0.000493         0.003894        0.000118
# 4       0.051311      0.002315         0.003926        0.000155
# 5       0.051320      0.002562         0.003910        0.000181
# 6       0.054563      0.001605         0.004091        0.000227
# 7       0.054284      0.001788         0.003898        0.000183
#
#    param_regressor__bootstrap  param_regressor__min_samples_leaf  \
# 0                        True                                  1
# 1                        True                                  1
# 2                        True                                  2
# 3                        True                                  2
# ...

# %% [markdown]
# # Evaluate
#
# + Which model has the best performance?

# %%
# Add column to show which pipeline results belongs to
res_a.insert(0, 'Pipe', 'A', True)
res_b.insert(0, 'Pipe', 'B', True)
res_c.insert(0, 'Pipe', 'C', True)
res_d.insert(0, 'Pipe', 'D', True)

# Merge all results and sort by lowest mean_test_neg_root_mean_squared_error
res_merged = pd.concat([res_a, res_b, res_c, res_d], ignore_index=True).sort_values('mean_test_neg_root_mean_squared_error', ascending=False)
res_merged
# Out:
#    Pipe  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 11    B       0.006544      0.000534         0.002108        0.000071
# 10    B       0.006589      0.000418         0.002149        0.000125
# 5     A       0.003051      0.000107         0.001485        0.000033
# 4     A       0.003047      0.000047         0.001489        0.000016
# 2     A       0.003282      0.000243         0.001612        0.000124
# 3     A       0.003227      0.000121         0.001615        0.000123
# 8     B       0.006265      0.000182         0.002041        0.000033
# 9     B       0.006374      0.000233         0.002031        0.000024
# 7     B       0.006415      0.000211         0.002097        0.000052
# 6     B       0.007209      0.000709         0.002240        0.000197
# 1     A       0.003540      0.000280         0.001555        0.000128
# 0     A       0.004421      0.001767         0.001727        0.000309
# ...

# %% [markdown]
# Based on the mean_test_neg_root_mean_squared_error (closer to 0 the better), Pipe B with parameters alpha = 3, selection = 'random' is the best performing model.

# %% [markdown]
# # Export
#
# + Save the best performing model to a pickle file.

# %%
#updating pipeline with best parameters and fitting it
pipe_b_up = Pipeline([
    ('preprocess', transform_col_2),
    ('regressor', linear_model.Lasso(alpha=3, selection='random'))
])

pipe_b_up.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num_sim_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler())]),
#                                                   ['ffmc', 'dmc', 'dc', 'isi']),
#                                                  ('num_yj_transforms',
#                                                   Pipeline(steps=[('standardizer',
#                                                                    StandardScaler()),
#                                                                   ('transformer',
#                                                                    PowerTransformer())]),
#                                                   ['temp', 'rh', 'wind',
#                                                    'rain']),
#                                                  ('cat_transforms',
# ...

# %%
with open('model.pkl', 'wb') as file:  
    pickle.dump(pipe_b_up, file)

# %% [markdown]
# # Explain
#
# + Use SHAP values to explain the following only for the best-performing model:
#
#     - Select an observation in your test set and explain which are the most important features that explain that observation's specific prediction.
#
#     - In general, across the complete training set, which features are the most and least important.
#
# + If you were to remove features from the model, which ones would you remove? Why? How would you test that these features are actually enhancing model performance?

# %%
data_transform = pipe_b_up.named_steps['preprocess'].transform(X_test)

explainer = shap.Explainer(
    pipe_b_up.named_steps['regressor'], 
    data_transform,
    feature_names = pipe_b_up.named_steps['preprocess'].get_feature_names_out())

shap_values = explainer(data_transform)

# %%
shap.plots.waterfall(shap_values[4])
# Out:
# Glyph 9 (	) missing from font(s) DejaVu Sans.

# %% [markdown]
# For this specific observation, features temp and dmc are the most important. WIth temp being more important contributing almost 3x than dmc pulling the predicted value to the right.

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# From this beeswarm graph, there are 2 very important features - dmc and temp. We can remove all other features from the model as they do not provide significant influence over the prediction. We can test this by doing another experiemnt where we create a model where we only use dmc and temp features and compare the neg_root_mean_squared_error (my performance metric of choice for the experiemnt above) of that model to a model that contains all features all together.

# %% [markdown]
# ## Criteria
#
# The [rubric](./assignment_3_rubric_clean.xlsx) contains the criteria for assessment.

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-3`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_3.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/production/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.

# %% [markdown]
# # Reference
#
# Cortez,Paulo and Morais,Anbal. (2008). Forest Fires. UCI Machine Learning Repository. https://doi.org/10.24432/C5D88D.
